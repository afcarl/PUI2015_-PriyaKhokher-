# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
sweden = pd.read_csv('sweden.csv')
bangladesh = pd.read_csv('bangladesh.csv')
niger = pd.read_csv('niger.csv')

# %%
print bangladesh[2:5]
print niger[2:5]
print sweden[2:5]
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 2      Bangladesh  2010  98.42540              NaN
# 3      Bangladesh  2009  99.47924              NaN
# 4      Bangladesh  2008  95.29395              NaN
#   Country or Area  Year     Value  Value Footnotes
# 2           Niger  2012  57.87286              NaN
# 3           Niger  2011  55.62370              NaN
# 4           Niger  2010  50.61060              NaN
#   Country or Area  Year     Value  Value Footnotes
# 2          Sweden  2012  99.27005              NaN
# 3          Sweden  2011  99.23112              NaN
# 4          Sweden  2010  99.07924              NaN

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig = plt.figure(figsize=(10,10),dpi=80,facecolor='w',edgecolor='k')
l=[]
l.append(np.array([sweden['Value'].iloc[4],sweden['Value'].iloc[3],sweden['Value'].iloc[2]]))
l.append(np.array([bangladesh['Value'].iloc[4],bangladesh['Value'].iloc[3],bangladesh['Value'].iloc[2]]))
l.append(np.array([niger['Value'].iloc[4],niger['Value'].iloc[3],niger['Value'].iloc[2]]))

#l.append(np.array([sweden['Value'].iloc[k],sweden['Value'].iloc[k],sweden['Value'].iloc[k]]))

k = 2
ax = fig.add_subplot(111,projection='3d')
#ax.text(50,50,0,'here',va='center',ha='center',color='yellow')
for c,z,i in zip(["#000000", "#E69F00", "#56B4E9"],[2010,2009,2008],[0,1,2]):
    ys = l[i]
    print 'ys',ys
    print 'z',z
    print 'xs',xs
    xs = np.array([1,2,3])
    #print xs
    cs = [c]*len(ys)
    
   
    
    ax.bar(xs,ys,zs=z,zdir='y',color=cs,alpha=0.6,align='center')
    #print 'bar'
    
    k = k+1
    ax.text(1,z,ys[0]+4,ys[0],va='center',ha='center',color='r',fontsize=12.5) 
    ax.text(2,z,ys[1]+4,ys[1],va='center',ha='center',color='r',fontsize=12.5)
    ax.text(3,z,ys[2]+4,ys[2],va='center',ha='center',color='r',fontsize=12.5)
    
    
    
ax.set_xlabel('Years',fontsize=15) 
ax.set_ylabel('Countries',fontsize=15)    
ax.set_zlabel('Percentage',fontsize=15)
ax.set_xticks([1.,2.,3.])
num_ticks = 3
ax.set_xticklabels(('2008','2009','2010'))
ax.set_yticks([2008,2009,2010])
num_ticks = 3
ax.set_yticklabels(('Niger','Bangladesh','Sweden'))
plt.title('Total net enrolment ratio in primary education of girls',fontsize=20)
#ax.text(1,2008,100,'here',va='center',ha='center',color='yellow')
plt.show()
# Out:
# ys [ 99.07924  99.23112  99.27005]
# z 2010
# xs [1 2 3]
# ys [ 95.29395  99.47924  98.4254 ]
# z 2009
# xs [1 2 3]
# ys [ 50.6106   55.6237   57.87286]
# z 2008
# xs [1 2 3]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig = plt.figure(figsize=(10,10),dpi=80,facecolor='w',edgecolor='k')

k = 2
ax = fig.add_subplot(111,projection='3d')
#ax.text(50,50,0,'here',va='center',ha='center',color='yellow')
for c,z in zip(["#000000", "#E69F00", "#56B4E9"],[2010,2009,2008]):
    ys = np.array([niger['Value'].iloc[k],bangladesh['Value'].iloc[k],sweden['Value'].iloc[k]])
    print ys
    print z
    xs = np.array([1,2,3])
    #print xs
    cs = [c]*len(ys)
    #print z
    #print cs
    
    
    ax.bar(xs,ys,zs=z,zdir='y',color=cs,alpha=0.6,align='center')
    #print 'bar'
    k = k+1
    ax.text(1,z,55,ys[0],va='center',ha='center',color='r',fontsize=12.5) 
    ax.text(2,z,ys[1]+5,ys[1],va='center',ha='center',color='r',fontsize=12.5)
    ax.text(3,z,ys[2]+5,ys[2],va='center',ha='center',color='r',fontsize=12.5)

    #ax.text(ax[0],ys[0],z[0],str(ys[0]),va='center',ha='center',color='yellow')
    
ax.set_xlabel('Countries',fontsize=15) 
ax.set_ylabel('Years',fontsize=15)    
ax.set_zlabel('Percentage',fontsize=15)
ax.set_xticks([1.,2.,3.])
num_ticks = 3
ax.set_xticklabels(('Niger','Bangladesh','Sweden'))
ax.set_yticks([2008,2009,2010])
num_ticks = 3
ax.set_yticklabels(('2008','2009','2010'))
plt.title('Total net enrolment ratio in primary education of girls',fontsize=20)
#ax.text(1,2008,100,'here',va='center',ha='center',color='yellow')
plt.show()
# Out:
# [ 57.87286  98.4254   99.27005]
# 2010
# [ 55.6237   99.47924  99.23112]
# 2009
# [ 50.6106   95.29395  99.07924]
# 2008
