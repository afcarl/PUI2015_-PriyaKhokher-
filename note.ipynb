# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that getstricky,but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %%
import numpy as np

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
np.random.seed(15)
k=np.random.normal(0.0,1,size=(100,2,2))
k
# Out:
# array([[[ -3.12328482e-01,   3.39284706e-01],
#         [ -1.55908534e-01,  -5.01789673e-01]],
#
#        [[  2.35568892e-01,  -1.76360526e+00],
#         [ -1.09586204e+00,  -1.08776574e+00]],
#
#        [[ -3.05170052e-01,  -4.73748372e-01],
#         [ -2.00594539e-01,   3.55196773e-01]],
#
#        [[  6.89517723e-01,   4.10589675e-01],
#         [ -5.64978437e-01,   5.99390690e-01]],
#
#        [[ -1.62936305e-01,   1.60021450e+00],
#         [  6.81627204e-01,   1.48801013e-02]],
#
#        [[ -8.77796322e-02,  -9.82117840e-01],
#         [  1.21690479e-01,  -1.13743729e+00]],
#
#        [[  3.49002578e-01,  -1.85851316e+00],
#         [ -1.16718189e+00,   1.42489683e+00]],
#
#        [[  1.49656536e+00,   1.28993206e+00],
#         [ -1.81174527e+00,  -1.49830721e+00]],
#
#        [[ -1.45014322e+00,  -1.69390696e+00],
#         [  2.27264028e-01,  -4.89734711e-01]],
#
#        [[ -5.28506514e-04,  -4.90252617e-01],
#         [ -7.93209422e-01,   2.04889876e+00]],
#
#        [[  6.03185439e-01,  -9.98202078e-01],
#         [  1.21504155e+00,  -6.67516491e-01]],
#
#        [[ -2.72505777e-01,   1.41677448e+00],
#         [ -7.82608958e-01,  -2.50320697e-01]],
#
#        [[ -3.08314461e-01,   1.72968803e+00],
#         [  1.97827237e+00,   2.19688032e-01]],
#
#        [[  1.89481985e+00,  -1.36809944e+00],
#         [ -1.91305386e-01,   1.28725753e+00]],
#
#        [[ -2.46883944e-01,   3.42551082e-01],
#         [  2.22717042e-01,   6.81593706e-01]],
#
#        [[  2.51448885e-01,  -1.48184894e+00],
#         [ -3.86821775e-01,  -7.33680711e-01]],
#
#        [[  5.85978205e-01,  -1.73578876e+00],
#         [ -8.26695212e-01,   1.18383423e+00]],
#
#        [[  3.55046044e-01,   2.44284991e+00],
#         [ -3.69254685e-02,  -2.71171405e+00]],
#
#        [[  9.91489633e-01,   1.92242770e-01],
#         [ -3.52792626e-01,  -1.33952283e+00]],
#
#        [[ -1.88672586e-01,   5.96586647e-01],
#         [  3.40454482e-01,   8.34253440e-02]],
#
#        [[  6.05992122e-01,   1.68937215e-01],
#         [ -1.03889125e+00,   2.85238084e-01]],
#
#        [[  5.02391385e-01,   1.93387498e+00],
#         [  4.83248779e-02,  -1.05176869e+00]],
#
#        [[  1.16658239e+00,   7.35467175e-01],
#         [ -5.63129933e-01,  -1.21300819e+00]],
#
#        [[  1.54812816e+00,  -1.69787534e+00],
#         [ -6.31792956e-01,   2.86366603e-01]],
#
#        [[ -1.04797207e+00,  -1.86450226e-01],
#         [  4.97554889e-01,  -4.04502199e-01]],
#
#        [[ -1.28410466e+00,  -6.14257102e-01],
#         [ -1.07869380e-01,   1.13362321e+00]],
#
#        [[ -1.03624629e+00,   1.51135743e+00],
#         [ -8.68273787e-01,   1.39223060e+00]],
#
#        [[  2.17509315e+00,   1.29902121e+00],
#         [ -1.88081362e-01,   1.66902327e+00]],
#
#        [[  1.15457421e+00,   4.81802396e-01],
#         [ -1.78037186e-01,  -3.86183134e-01]],
#
#        [[ -1.30074289e-01,   2.35962357e+00],
#         [  5.16999712e-01,   4.41354670e-01]],
#
#        [[ -4.75724547e-01,   3.28382994e-01],
#         [ -2.82805534e-01,  -7.20218945e-01]],
#
#        [[  8.84588675e-02,  -4.72515661e-01],
#         [  1.29971965e-01,  -1.06833786e-01]],
#
#        [[ -7.04302805e-01,   5.17177497e-01],
#         [  5.80846212e-01,  -2.82179205e+00]],
#
#        [[ -2.49617418e-01,  -1.77093757e-01],
#         [ -2.56335832e-01,   1.27151467e+00]],
#
#        [[  8.09784028e-02,  -4.17940714e-01],
#         [ -7.66949543e-01,   6.31566106e-01]],
#
#        [[ -1.62644675e+00,  -3.14025273e-01],
#         [ -6.15472121e-01,  -3.98984268e-01]],
#
#        [[ -3.18563954e-01,  -1.18083045e+00],
#         [ -1.17284370e+00,  -5.23205813e-02]],
#
#        [[ -8.46183890e-01,   1.41449195e+00],
#         [  3.35853514e-01,  -1.11286049e+00]],
#
#        [[  5.13106147e-01,  -2.28318764e-01],
#         [  2.33787366e-01,   1.54159367e+00]],
#
#        [[  9.18674296e-01,  -9.13569124e-01],
#         [  5.02448117e-01,  -4.28064087e-01]],
#
#        [[  1.02301209e+00,  -3.22204871e-02],
#         [ -1.59430184e+00,  -3.46625972e+00]],
#
#        [[ -6.77860689e-01,  -8.28270940e-01],
#         [ -7.89141838e-01,   2.17363077e+00]],
#
#        [[  1.16913480e-01,   8.69209877e-01],
#         [ -9.51972452e-01,   6.55838623e-01]],
#
#        [[ -5.54024847e-01,  -1.57161544e+00],
#         [ -3.24940018e-01,  -5.43115976e-02]],
#
#        [[ -1.08560129e+00,   1.42994238e+00],
#         [  5.06833958e-02,  -1.54651858e+00]],
#
#        [[ -2.45475861e+00,   7.61347313e-01],
#         [  7.91155576e-01,   6.38751797e-01]],
#
#        [[ -9.22685382e-01,  -9.01962048e-01],
#         [  5.87375533e-01,  -4.11402172e-01]],
#
#        [[  5.06873874e-03,   6.80073835e-01],
#         [  1.12290280e+00,  -7.67417183e-01]],
#
#        [[ -1.51305463e-01,   2.68818087e-01],
#         [ -6.05659140e-01,   9.81575954e-01]],
#
#        [[ -1.03729344e+00,   4.73742512e-01],
#         [ -4.19226173e-01,   1.29051387e+00]],
#
#        [[  1.45191840e-01,  -6.23051612e-01],
#         [ -2.69255715e-01,  -1.24513511e+00]],
#
#        [[  7.27388647e-01,  -1.38485916e-01],
#         [ -2.07172028e-01,   4.70944360e-01]],
#
#        [[  5.57052446e-01,  -3.74770679e-01],
#         [ -1.12788246e+00,   1.17112385e+00]],
#
#        [[  4.52248649e-01,   1.74116531e-01],
#         [  8.80931591e-01,  -2.41426597e-01]],
#
#        [[  1.60441582e+00,  -1.61384881e-01],
#         [ -2.04782353e-01,   1.84031574e-01]],
#
#        [[ -3.03423172e-01,  -1.11442766e-01],
#         [  1.77008250e-01,  -6.51433907e-01]],
#
#        [[  4.78908774e-01,   9.56847853e-02],
#         [  1.98117750e+00,  -2.69872307e-01]],
#
#        [[ -7.15540561e-01,  -8.46867429e-01],
#         [  4.51804357e-01,   3.28499584e-01]],
#
#        [[ -8.96613315e-01,   8.83265178e-01],
#         [ -1.57793062e+00,  -8.94427573e-01]],
#
#        [[ -4.30373815e-01,  -2.84448104e-02],
#         [ -8.47429455e-01,   1.40732819e+00]],
#
#        [[  1.16421582e+00,   1.70619778e-01],
#         [  1.54418283e-01,   9.56198149e-03]],
#
#        [[  8.55923054e-02,   8.05420519e-01],
#         [  8.82914963e-01,   5.23790549e-01]],
#
#        [[ -3.21153349e-01,  -1.45463775e+00],
#         [ -1.65555653e+00,   2.48738512e-01]],
#
#        [[ -1.39627125e+00,  -5.30414082e-01],
#         [  1.13944002e+00,   3.88412621e-01]],
#
#        [[  1.05311188e-01,   1.60014203e-01],
#         [  6.82572393e-01,   6.81193421e-01]],
#
#        [[ -9.18334329e-01,  -1.14637584e+00],
#         [ -8.36161599e-01,  -8.37278805e-02]],
#
#        [[  2.18955970e+00,   1.89807073e-01],
#         [  8.03553697e-02,   1.04510442e+00]],
#
#        [[  9.21814892e-01,  -7.19418761e-01],
#         [ -2.13849727e+00,   2.59330997e+00]],
#
#        [[ -4.02176154e-01,  -5.54288556e-01],
#         [  1.19443515e+00,  -1.05083253e+00]],
#
#        [[ -3.70339350e-01,  -1.51160633e+00],
#         [  9.17658433e-01,  -7.78423602e-01]],
#
#        [[  4.55627346e-02,   7.56033116e-01],
#         [ -2.41958437e-01,   2.27398764e+00]],
#
#        [[ -1.85205981e-01,  -1.68299157e+00],
#         [  7.39227306e-01,   7.98269322e-01]],
#
#        [[  8.54735659e-01,  -8.13024609e-01],
#         [ -6.26649593e-01,  -1.99881134e-01]],
#
#        [[  8.03737174e-01,  -2.59304156e-01],
#         [  1.19964312e+00,   6.87752691e-01]],
#
#        [[  5.05657864e-01,  -9.42888571e-01],
#         [ -2.05270649e+00,  -4.28597483e-03]],
#
#        [[  1.24996363e+00,   7.59761834e-01],
#         [ -1.03583219e+00,   6.10614833e-01]],
#
#        [[ -8.48716028e-02,   3.95389845e-01],
#         [ -1.34293696e+00,  -1.13880190e+00]],
#
#        [[ -3.53575693e-01,   1.05640215e+00],
#         [ -4.76943655e-01,  -1.55566599e-02]],
#
#        [[  1.21959898e+00,  -6.11289570e-01],
#         [ -5.86190286e-01,  -7.65630111e-01]],
#
#        [[  1.10829077e+00,  -5.85745374e-01],
#         [ -1.46821813e+00,  -7.39171298e-01]],
#
#        [[  1.68487391e-01,   9.34814456e-02],
#         [  5.02783440e-01,   1.14640309e+00]],
#
#        [[  2.12301248e-01,  -5.59704168e-01],
#         [ -1.98392087e+00,   1.65328710e-01]],
#
#        [[  7.05072699e-01,   4.24757562e-01],
#         [  5.06070094e-01,  -7.23604444e-01]],
#
#        [[  5.33213229e-01,  -1.83036927e+00],
#         [ -1.52840499e+00,  -1.86949348e+00]],
#
#        [[  7.81879879e-01,   6.46062655e-01],
#         [  6.38684564e-01,   1.69878718e+00]],
#
#        [[ -1.24706616e+00,   2.57464725e-01],
#         [ -4.10707858e-01,  -7.18842784e-01]],
#
#        [[  7.70557068e-01,  -4.01575469e-01],
#         [ -1.09640949e+00,   7.27909470e-01]],
#
#        [[ -4.98431240e-01,  -1.41303925e-01],
#         [  8.25853351e-01,  -3.27747145e-01]],
#
#        [[ -3.79066920e-01,   3.73144054e-01],
#         [  1.61165248e+00,  -1.63808870e+00]],
#
#        [[  1.64838597e+00,   9.85603101e-01],
#         [  4.42198545e-01,   5.80467287e-01]],
#
#        [[ -1.22873400e+00,   3.81003994e-01],
#         [  1.08076183e+00,   1.16765206e-01]],
#
#        [[ -1.56948555e+00,  -3.19835512e-01],
#         [ -1.42546408e+00,  -1.27528006e+00]],
#
#        [[ -1.12229590e+00,   7.94460946e-01],
#         [  1.52788009e+00,  -2.00371541e-01]],
#
#        [[  1.07772890e+00,  -5.97182078e-01],
#         [ -4.35254316e-01,   1.21800532e+00]],
#
#        [[  2.16365306e+00,   1.23592114e+00],
#         [ -2.53478242e+00,  -4.51652396e-01]],
#
#        [[  1.76614453e-01,   1.72604030e-01],
#         [ -1.00176506e+00,   2.67147758e+00]],
#
#        [[ -1.98712012e+00,  -9.20552611e-02],
#         [ -1.00732405e+00,  -4.18640409e-01]],
#
#        [[ -7.79749960e-02,  -7.79220767e-01],
#         [  7.04264343e-02,  -1.76497698e+00]],
#
#        [[ -1.09820719e+00,   2.54699898e-01],
#         [ -1.41801990e+00,   3.08483119e-01]],
#
#        [[ -6.95547976e-01,  -1.30541217e+00],
#         [ -6.60078776e-02,  -8.27229420e-01]]])

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
q=np.random.normal(1.0,2,size=(50,2,2))
q
# Out:
# array([[[ 4.37644816,  1.08155995],
#         [ 4.21844016, -0.94979473]],
#
#        [[ 3.13175102,  0.89190789],
#         [ 2.35926808, -0.15513714]],
#
#        [[ 3.27024276,  5.14749207],
#         [-0.61826129, -0.84962748]],
#
#        [[ 5.13305309, -1.39156752],
#         [ 0.5326497 , -0.44845171]],
#
#        [[-2.30530313, -0.04438867],
#         [ 0.56243336, -3.67126607]],
#
#        [[ 3.06804691,  1.08193332],
#         [-4.46149719,  0.89585346]],
#
#        [[ 5.25586427, -1.11633579],
#         [ 1.0320381 ,  4.31206672]],
#
#        [[-3.91218976,  3.45614835],
#         [ 4.7453728 ,  4.00125279]],
#
#        [[-1.62338866,  2.48104211],
#         [ 0.54067203,  4.0355831 ]],
#
#        [[ 3.26366292,  0.10312009],
#         [ 0.83525124, -0.92917189]],
#
#        [[ 0.14533322,  0.32159657],
#         [ 0.95877852,  0.40451428]],
#
#        [[-0.69180167,  1.05734827],
#         [-0.02976579,  0.8068024 ]],
#
#        [[-0.73045362,  3.69983087],
#         [ 3.41420374,  3.31165868]],
#
#        [[-1.24305565,  1.38323854],
#         [ 0.24691481,  1.01326782]],
#
#        [[ 1.95264971,  2.61964792],
#         [-0.77331483,  3.45154907]],
#
#        [[ 3.56012285,  3.34733172],
#         [-0.36430101,  1.40579547]],
#
#        [[ 1.00132571, -0.52020456],
#         [-0.72148467,  0.85469912]],
#
#        [[-1.12889496, -1.85392625],
#         [ 0.42579418,  0.81888462]],
#
#        [[ 2.71755252,  4.20878207],
#         [-1.59719669,  1.48643509]],
#
#        [[ 2.20842806, -1.08483967],
#         [ 0.14249985,  1.09298843]],
#
#        [[ 0.40314835,  2.41522779],
#         [ 4.30398038,  4.88453513]],
#
#        [[ 0.62379575,  0.16808115],
#         [ 2.95081179,  0.50913717]],
#
#        [[ 0.82706474,  2.49092438],
#         [-0.80227069,  3.98829179]],
#
#        [[ 0.27862677,  1.66246909],
#         [-0.27684964,  1.57521036]],
#
#        [[-0.72736845, -2.6822885 ],
#         [-0.32821347,  1.91438815]],
#
#        [[-2.2001136 ,  2.04575337],
#         [ 4.35081094,  0.37367831]],
#
#        [[ 2.54953051,  0.37098388],
#         [ 2.91411568,  0.52824363]],
#
#        [[-3.45119214, -0.04517852],
#         [ 3.48569375,  0.67129139]],
#
#        [[-0.56715401,  1.53640615],
#         [-1.95430049,  4.38944668]],
#
#        [[-1.0235748 ,  2.02227358],
#         [ 1.56965944,  0.2565414 ]],
#
#        [[-1.61759115,  1.11940111],
#         [ 0.87095785,  0.84235519]],
#
#        [[-2.83821763,  0.99168569],
#         [ 0.66464105,  0.87357385]],
#
#        [[ 0.87049181, -0.41506275],
#         [-1.75926336,  1.56462298]],
#
#        [[-1.35908807, -0.93437995],
#         [ 0.94144034,  4.33598425]],
#
#        [[ 2.0580797 ,  3.07311266],
#         [ 0.34010719,  0.43638384]],
#
#        [[ 1.91386799,  1.55299135],
#         [ 1.46869573,  1.82850703]],
#
#        [[ 0.32783584,  0.92561247],
#         [ 0.98138807,  4.27007356]],
#
#        [[ 0.79823992,  1.16343169],
#         [ 2.60043054,  2.58121465]],
#
#        [[ 2.55216258, -2.4810933 ],
#         [ 0.72739429,  0.47675553]],
#
#        [[ 0.60586075,  1.55300729],
#         [ 2.66205152,  1.64460269]],
#
#        [[-0.09025305,  0.38688694],
#         [-2.28143744, -0.95212545]],
#
#        [[ 3.61115847,  0.98847718],
#         [-2.11611227,  0.32789976]],
#
#        [[ 1.44461201,  1.66940278],
#         [-1.53551991,  0.01221133]],
#
#        [[ 3.72150753,  6.93730415],
#         [ 1.01355181, -1.50698   ]],
#
#        [[-0.54203577, -0.56535894],
#         [ 0.46354956,  2.93306981]],
#
#        [[ 4.60867387, -3.05080272],
#         [ 0.70105652,  1.66504869]],
#
#        [[ 0.46148173,  0.45753917],
#         [ 0.43578947,  3.98511487]],
#
#        [[ 1.89494838, -0.28509298],
#         [ 4.74399401,  2.8580003 ]],
#
#        [[-1.61605093, -1.33162574],
#         [ 1.19141415,  1.91679134]],
#
#        [[-1.43149693,  3.56191326],
#         [ 1.9338492 ,  2.87057977]]])

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig=plt.figure()
ax = fig.add_subplot(111) 
m1=float(np.mean(k))
m2=float(np.mean(q))
s1=float(np.std(k))
s2=float(np.std(q))
sample_100=plt.scatter(k,k.transpose(),color='k',label= '%s %f %s %f' % ('Sample-100 Mean',m1,"std. dev",s1))
sample_50=plt.scatter(q,q.transpose(),color= 'g',label='%s %f %s %f' % ('Sample-50 Mean',m2,"std. dev",s2))

plt.legend()
ax.set_xlabel("One dimension")
ax.set_ylabel("Second Dimension")
ax.legend()
plt.show()
